# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik5412/Deep-Learning-Projects/blob/main/ANN%20Model/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/zomato.csv', engine= 'python', on_bad_lines='skip')

df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
print(df.shape)
df.isna().sum()
# Out:
# (3443, 17)
# url                               0
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                            466
# votes                             0
# phone                            48
# location                          1
# rest_type                        14
# dish_liked                     2053
# cuisines                          4
# approx_cost(for two people)       4
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
print(df.columns)
unwanted_cols = ['menu_item','phone']

df= df.drop(columns=unwanted_cols)

df.head(2)
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes      location      rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari  Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
#
#                                         reviews_list listed_in(type)  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...          Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari

# %%
df['total address'] = df['address'] + ', ' +df['location'] + ', ' +  df['listed_in(city)']
df['food items'] = df['dish_liked'] + ', ' +df['cuisines']
original_df = df.copy()

df = df[['listed_in(type)','rest_type','total address','book_table','online_order', 'rate', 'approx_cost(for two people)']]
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address book_table online_order  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...        Yes          Yes
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         No          Yes
#
#     rate approx_cost(for two people)
# 0  4.1/5                         800
# 1  4.1/5                         800

# %%
df.to_csv('cleaned_df.csv')

# %%
from nltk.tag.brill import Word
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lematizer = WordNetLemmatizer()

def preprocessing_data (text) -> str:

    text = str(text)
    # Converting the text into lower case
    text = text.lower()

    # Removing punctuvations
    text = re.sub(r'[^a-zA-Z0-9\s]','',text)

    # Removing stop words
    words = [w for w in text.split() if w not in stop_words]

    # Lemotization
    words = [lematizer.lemmatize(w) for w in words]

    return ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df['total address'] = ' - ' + df['total address']
df['total address'] = df['total address'].apply(preprocessing_data)
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address book_table online_order  \
# 0  942 21st main road 2nd stage banashankari bang...        Yes          Yes
# 1  2nd floor 80 foot road near big bazaar 6th blo...         No          Yes
#
#     rate approx_cost(for two people)
# 0  4.1/5                         800
# 1  4.1/5                         800

# %%
df.loc[df['rate'] == 'NEW','rate'] = df['rate'].mode()[0]
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#        '2.5 /5', '2.6 /5', '4.5 /5'], dtype=object)

# %%
df['rate'] = df['rate'].apply(lambda x: x.replace('/5','')).str.strip().astype('float')
df['book_table'] = df['book_table'].map({'Yes': 1, 'No': 0}).astype('int')
df['online_order'] = df['online_order'].map({'Yes': 1, 'No': 0}).astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1376 entries, 0 to 3442
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listed_in(type)              1376 non-null   object
#  1   rest_type                    1376 non-null   object
#  2   total address                1376 non-null   object
#  3   book_table                   1376 non-null   int64
#  4   online_order                 1376 non-null   int64
#  5   rate                         1376 non-null   float64
#  6   approx_cost(for two people)  1376 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 86.0+ KB

# %%
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate approx_cost(for two people)
# 0             1   4.1                         800
# 1             1   4.1                         800

# %%
df['rest_type'] = df['rest_type'].apply(preprocessing_data)

df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  casual dining
# 1          Buffet  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate approx_cost(for two people)
# 0             1   4.1                         800
# 1             1   4.1                         800

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].apply(lambda x: x.replace(',', '')).astype(float)

# %%
df['listed_in(type)'] = df['listed_in(type)'].replace('Drinks & nightlife' , 'Drinks and Nightlife')
df['listed_in(type)'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks and Nightlife'], dtype=object)

# %%
df.head()
# Out:
#   listed_in(type)           rest_type  \
# 0          Buffet       casual dining
# 1          Buffet       casual dining
# 2          Buffet  cafe casual dining
# 3          Buffet          quick bite
# 4          Buffet       casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
# 2  1112 next kims medical college 17th cross 2nd ...           0
# 3  1st floor annakuteera 3rd stage banashankari b...           0
# 4  10 3rd floor lakshmi associate gandhi bazaar m...           0
#
#    online_order  rate  approx_cost(for two people)
# 0             1   4.1                        800.0
# 1             1   4.1                        800.0
# 2             1   3.8                        800.0
# 3             0   3.7                        300.0
# 4             0   3.8                        600.0

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df['listed_in(type)'] = label_encoder.fit_transform(df['listed_in(type)'])
df.head(2)
# Out:
#    listed_in(type)      rest_type  \
# 0                0  casual dining
# 1                0  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate  approx_cost(for two people)
# 0             1   4.1                        800.0
# 1             1   4.1                        800.0

# %%
df['final_phrase'] = df['rest_type'] + ' ' + df['total address']

df.head(2)
# Out:
#    listed_in(type)      rest_type  \
# 0                0  casual dining
# 1                0  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate  approx_cost(for two people)  \
# 0             1   4.1                        800.0
# 1             1   4.1                        800.0
#
#                                         final_phrase
# 0  casual dining 942 21st main road 2nd stage ban...
# 1  casual dining 2nd floor 80 foot road near big ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features= 1000)

tfidf_matrix = tfidf.fit_transform(df['final_phrase']).toarray()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

cost_matrix = scaler.fit_transform(df.drop(columns= ['rest_type','rate', 'total address','final_phrase']))

# %%
final_matrix = np.hstack((tfidf_matrix, cost_matrix))

final_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  2.2985006 ,
#          0.53589578,  0.80343513],
#        [ 0.        ,  0.        ,  0.        , ..., -0.43506623,
#          0.53589578,  0.80343513],
#        [ 0.        ,  0.        ,  0.        , ..., -0.43506623,
#          0.53589578,  0.80343513],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  2.2985006 ,
#          0.53589578,  1.48173481],
#        [ 0.        ,  0.        ,  0.        , ..., -0.43506623,
#          0.53589578,  0.12513545],
#        [ 0.        ,  0.        ,  0.        , ...,  2.2985006 ,
#          0.53589578,  2.16003449]])

# %%
df.loc[0:3, ['final_phrase','listed_in(type)', 'book_table', 'online_order', 'approx_cost(for two people)']]
# Out:
#                                         final_phrase  listed_in(type)  \
# 0  casual dining 942 21st main road 2nd stage ban...                0
# 1  casual dining 2nd floor 80 foot road near big ...                0
# 2  cafe casual dining 1112 next kims medical coll...                0
# 3  quick bite 1st floor annakuteera 3rd stage ban...                0
#
#    book_table  online_order  approx_cost(for two people)
# 0           1             1                        800.0
# 1           0             1                        800.0
# 2           0             1                        800.0
# 3           0             0                        300.0

# %%
final_matrix[0:3]
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  2.2985006 ,
#          0.53589578,  0.80343513],
#        [ 0.        ,  0.        ,  0.        , ..., -0.43506623,
#          0.53589578,  0.80343513],
#        [ 0.        ,  0.        ,  0.        , ..., -0.43506623,
#          0.53589578,  0.80343513]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
network = keras.Sequential([
    layers.Dense(256, activation='relu',input_dim=final_matrix.shape[1]),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='swish'),
    layers.Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
network.compile(optimizer='adam', loss='mean_squared_error', metrics= ['mae'])

# %%
history =network.fit(final_matrix, df['rate'], epochs= 150, batch_size=400, validation_split=0.2, verbose= 1)
# Out:
# Epoch 1/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 14.3889 - mae: 3.7683 - val_loss: 13.4832 - val_mae: 3.6504
# Epoch 2/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.5659 - mae: 3.5187 - val_loss: 11.4739 - val_mae: 3.3638
# Epoch 3/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 10.4008 - mae: 3.1942 - val_loss: 8.8909 - val_mae: 2.9526
# Epoch 4/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 7.7143 - mae: 2.7310 - val_loss: 5.7426 - val_mae: 2.3513
# Epoch 5/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.5632 - mae: 2.0507 - val_loss: 2.4980 - val_mae: 1.5016
# Epoch 6/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.6938 - mae: 1.1508 - val_loss: 0.4965 - val_mae: 0.5672
# Epoch 7/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7233 - mae: 0.6693 - val_loss: 0.9712 - val_mae: 0.7948
# Epoch 8/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.5750 - mae: 1.0516 - val_loss: 1.0667 - val_mae: 0.8769
# Epoch 9/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.2315 - mae: 0.9288 - val_loss: 0.3644 - val_mae: 0.4494
# Epoch 10/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.3888 - mae: 0.4807 - val_loss: 0.3013 - val_mae: 0.4582
# Epoch 11/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3287 - mae: 0.4720 - val_loss: 0.5986 - val_mae: 0.6943
# Epoch 12/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5308 - mae: 0.6335 - val_loss: 0.7244 - val_mae: 0.7741
# Epoch 13/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.
150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0456 - mae: 0.1687 - val_loss: 0.0846 - val_mae: 0.1821
# Epoch 84/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0419 - mae: 0.1558 - val_loss: 0.0826 - val_mae: 0.1779
# Epoch 85/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0414 - mae: 0.1570 - val_loss: 0.0812 - val_mae: 0.1754
# Epoch 86/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0451 - mae: 0.1626 - val_loss: 0.0815 - val_mae: 0.1773
# Epoch 87/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0396 - mae: 0.1541 - val_loss: 0.0828 - val_mae: 0.1818
# Epoch 88/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0434 - mae: 0.1627 - val_loss: 0.0840 - val_mae: 0.1853
# Epoch 89/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0416 - mae: 0.1565 - val_loss: 0.0855 - val_mae: 0.1894
# Epoch 90/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0385 - mae: 0.1529 - val_loss: 0.0834 - val_mae: 0.1826
# Epoch 91/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0410 - mae: 0.1573 - val_loss: 0.0803 - val_mae: 0.1733
# Epoch 92/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0402 - mae: 0.1565 - val_loss: 0.0789 - val_mae: 0.1697
# Epoch 93/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0362 - mae: 0.1480 - val_loss: 0.0790 - val_mae: 0.1709
# Epoch 94/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0392 - mae: 0.1567 - val_loss: 0.0799 - val_mae: 0.1745
# Epoch 95/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0389 - mae: 0.1539 - val_loss: 0.0802 - val_mae: 0.1763
# Epoch 96/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0363 - mae: 0.1489 - val_loss: 0.0778 - val_mae: 0.1701
# Epoch 97/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0371 - mae: 0.1499 - val_loss: 0.0764 - val_mae: 0.1666
# Epoch 98/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0383 - mae: 0.1528 - val_loss: 0.0767 - val_mae: 0.1681
# Epoch 99/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0376 - mae: 0.1503 - val_loss: 0.0785 - val_mae: 0.1728
# Epoch 100/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0335 - mae: 0.1443 - val_loss: 0.0793 - val_mae: 0.1747
# Epoch 101/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0341 - mae: 0.1442 - val_loss: 0.0778 - val_mae: 0.1698
# Epoch 102/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0355 - mae: 0.1461 - val_loss: 0.0762 - val_mae: 0.1657
# Epoch 103/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0363 - mae: 0.1480 - val_loss: 0.0762 - val_mae: 0.1661
# Epoch 104/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0363 - mae: 0.1481 - val_loss: 0.0771 - val_mae: 0.1695
# Epoch 105/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0362 - mae: 0.1466 - val_loss: 0.0762 - val_mae: 0.1679
# Epoch 106/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0341 - mae: 0.1441 - val_loss: 0.0747 - val_mae: 0.1634
# Epoch 107/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0332 - mae: 0.1418 - val_loss: 0.0737 - val_mae: 0.1604
# Epoch 108/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0351 - mae: 0.1443 - val_loss: 0.0739 - val_mae: 0.1601
# Epoch 109/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0347 - mae: 0.1454 - val_loss: 0.0751 - val_mae: 0.1628
# Epoch 110/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0331 - mae: 0.1419 - val_loss: 0.0758 - val_mae: 0.1645
# Epoch 111/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0323 - mae: 0.1411 - val_loss: 0.0765 - val_mae: 0.1676
# Epoch 112/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0335 - mae: 0.1427 - val_loss: 0.0760 - val_mae: 0.1671
# Epoch 113/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0333 - mae: 0.1400 - val_loss: 0.0730 - val_mae: 0.1591
# Epoch 114/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0330 - mae: 0.1397 - val_loss: 0.0714 - val_mae: 0.1557
# Epoch 115/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0299 - mae: 0.1362 - val_loss: 0.0723 - val_mae: 0.1589
# Epoch 116/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0300 - mae: 0.1367 - val_loss: 0.0727 - val_mae: 0.1607
# Epoch 117/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0295 - mae: 0.1331 - val_loss: 0.0712 - val_mae: 0.1560
# Epoch 118/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0307 - mae: 0.1364 - val_loss: 0.0709 - val_mae: 0.1553
# Epoch 119/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0307 - mae: 0.1352 - val_loss: 0.0724 - val_mae: 0.1598
# Epoch 120/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0310 - mae: 0.1380 - val_loss: 0.0731 - val_mae: 0.1618
# Epoch 121/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0287 - mae: 0.1343 - val_loss: 0.0723 - val_mae: 0.1583
# Epoch 122/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0303 - mae: 0.1361 - val_loss: 0.0707 - val_mae: 0.1539
# Epoch 123/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0276 - mae: 0.1302 - val_loss: 0.0705 - val_mae: 0.1533
# Epoch 124/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0290 - mae: 0.1329 - val_loss: 0.0697 - val_mae: 0.1512
# Epoch 125/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0289 - mae: 0.1336 - val_loss: 0.0696 - val_mae: 0.1508
# Epoch 126/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0295 - mae: 0.1328 - val_loss: 0.0700 - val_mae: 0.1527
# Epoch 127/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0282 - mae: 0.1315 - val_loss: 0.0711 - val_mae: 0.1564
# Epoch 128/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0288 - mae: 0.1327 - val_loss: 0.0710 - val_mae: 0.1549
# Epoch 129/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0272 - mae: 0.1290 - val_loss: 0.0715 - val_mae: 0.1547
# Epoch 130/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0290 - mae: 0.1322 - val_loss: 0.0730 - val_mae: 0.1588
# Epoch 131/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0278 - mae: 0.1305 - val_loss: 0.0725 - val_mae: 0.1571
# Epoch 132/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0286 - mae: 0.1331 - val_loss: 0.0711 - val_mae: 0.1536
# Epoch 133/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0290 - mae: 0.1321 - val_loss: 0.0701 - val_mae: 0.1508
# Epoch 134/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0278 - mae: 0.1270 - val_loss: 0.0691 - val_mae: 0.1473
# Epoch 135/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0261 - mae: 0.1264 - val_loss: 0.0689 - val_mae: 0.1462
# Epoch 136/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0275 - mae: 0.1295 - val_loss: 0.0698 - val_mae: 0.1491
# Epoch 137/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0285 - mae: 0.1298 - val_loss: 0.0706 - val_mae: 0.1517
# Epoch 138/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0252 - mae: 0.1220 - val_loss: 0.0709 - val_mae: 0.1522
# Epoch 139/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0249 - mae: 0.1229 - val_loss: 0.0700 - val_mae: 0.1498
# Epoch 140/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0261 - mae: 0.1232 - val_loss: 0.0690 - val_mae: 0.1478
# Epoch 141/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0249 - mae: 0.1213 - val_loss: 0.0687 - val_mae: 0.1470
# Epoch 142/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0267 - mae: 0.1272 - val_loss: 0.0694 - val_mae: 0.1501
# Epoch 143/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0254 - mae: 0.1238 - val_loss: 0.0700 - val_mae: 0.1525
# Epoch 144/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0270 - mae: 0.1257 - val_loss: 0.0694 - val_mae: 0.1508
# Epoch 145/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0267 - mae: 0.1280 - val_loss: 0.0681 - val_mae: 0.1478
# Epoch 146/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0237 - mae: 0.1205 - val_loss: 0.0688 - val_mae: 0.1503
# Epoch 147/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0242 - mae: 0.1206 - val_loss: 0.0692 - val_mae: 0.1516
# Epoch 148/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0245 - mae: 0.1227 - val_loss: 0.0682 - val_mae: 0.1484
# Epoch 149/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0254 - mae: 0.1235 - val_loss: 0.0663 - val_mae: 0.1433
# Epoch 150/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0237 - mae: 0.1189 - val_loss: 0.0671 - val_mae: 0.1456

# %%
network.save('network.keras')

# %%
import joblib

joblib.dump(scaler, 'scaler.plk')
joblib.dump(tfidf, 'tfidf.plk')
# Out:
# ['tfidf.plk']
