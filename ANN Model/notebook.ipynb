# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik5412/Deep-Learning-Projects/blob/main/ANN%20Model/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/zomato.csv', engine= 'python', on_bad_lines='skip')

df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
print(df.shape)
df.isna().sum()
# Out:
# (51155, 17)
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1203
# location                          21
# rest_type                        224
# dish_liked                     28074
# cuisines                          45
# approx_cost(for two people)      344
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
print(df.columns)
unwanted_cols = ['menu_item','phone']

df= df.drop(columns=unwanted_cols)

df.head(2)
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes      location      rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari  Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
#
#                                         reviews_list listed_in(type)  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...          Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari

# %%
df['total address'] = df['address'] + ', ' +df['location'] + ', ' +  df['listed_in(city)']
df['food items'] = df['dish_liked'] + ', ' +df['cuisines']
original_df = df.copy()

df = df[['listed_in(type)','rest_type','total address','book_table','online_order', 'rate', 'approx_cost(for two people)']]
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address book_table online_order  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...        Yes          Yes
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         No          Yes
#
#     rate approx_cost(for two people)
# 0  4.1/5                         800
# 1  4.1/5                         800

# %%
df.to_csv('cleaned_df.csv')

# %%
from nltk.tag.brill import Word
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lematizer = WordNetLemmatizer()

def preprocessing_data (text) -> str:

    text = str(text)
    # Converting the text into lower case
    text = text.lower()

    # Removing punctuvations
    text = re.sub(r'[^a-zA-Z0-9\s]','',text)

    # Removing stop words
    words = [w for w in text.split() if w not in stop_words]

    # Lemotization
    words = [lematizer.lemmatize(w) for w in words]

    return ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['total address'] = ' - ' + df['total address']
df['total address'] = df['total address'].apply(preprocessing_data)
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address book_table online_order  \
# 0  942 21st main road 2nd stage banashankari bang...        Yes          Yes
# 1  2nd floor 80 foot road near big bazaar 6th blo...         No          Yes
#
#     rate approx_cost(for two people)
# 0  4.1/5                         800
# 1  4.1/5                         800

# %%
df.loc[df['rate'] == 'NEW','rate'] = df['rate'].mode()[0]
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#        '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5', '4.4 /5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5', '3.3 /5',
#        '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5', '3.5 /5',
#        '3.1 /5', '4.8 /5', '2.3 /5', '2.4 /5', '4.7 /5', '2.2 /5',
#        '2.0 /5', '2.1 /5', '1.8 /5'], dtype=object)

# %%
df['rate'] = df['rate'].apply(lambda x: x.replace('/5','')).str.strip().astype('float')
df['book_table'] = df['book_table'].map({'Yes': 1, 'No': 0}).astype('int')
df['online_order'] = df['online_order'].map({'Yes': 1, 'No': 0}).astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22643 entries, 0 to 51153
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listed_in(type)              22643 non-null  object
#  1   rest_type                    22643 non-null  object
#  2   total address                22643 non-null  object
#  3   book_table                   22643 non-null  int64
#  4   online_order                 22643 non-null  int64
#  5   rate                         22643 non-null  float64
#  6   approx_cost(for two people)  22643 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate approx_cost(for two people)
# 0             1   4.1                         800
# 1             1   4.1                         800

# %%
df['rest_type'] = df['rest_type'].apply(preprocessing_data)

df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  casual dining
# 1          Buffet  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate approx_cost(for two people)
# 0             1   4.1                         800
# 1             1   4.1                         800

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].apply(lambda x: x.replace(',', '')).astype(float)

# %%
df['listed_in(type)'] = df['listed_in(type)'].replace('Drinks & nightlife' , 'Drinks and Nightlife')
df['listed_in(type)'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks and Nightlife', 'Pubs and bars'], dtype=object)

# %%
df.head()
# Out:
#   listed_in(type)           rest_type  \
# 0          Buffet       casual dining
# 1          Buffet       casual dining
# 2          Buffet  cafe casual dining
# 3          Buffet          quick bite
# 4          Buffet       casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
# 2  1112 next kims medical college 17th cross 2nd ...           0
# 3  1st floor annakuteera 3rd stage banashankari b...           0
# 4  10 3rd floor lakshmi associate gandhi bazaar m...           0
#
#    online_order  rate  approx_cost(for two people)
# 0             1   4.1                        800.0
# 1             1   4.1                        800.0
# 2             1   3.8                        800.0
# 3             0   3.7                        300.0
# 4             0   3.8                        600.0

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df['listed_in(type)'] = label_encoder.fit_transform(df['listed_in(type)'])
df.head(2)
# Out:
#    listed_in(type)      rest_type  \
# 0                0  casual dining
# 1                0  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate  approx_cost(for two people)
# 0             1   4.1                        800.0
# 1             1   4.1                        800.0

# %%
df['final_phrase'] = df['rest_type'] + ' ' + df['total address']

df.head(2)
# Out:
#    listed_in(type)      rest_type  \
# 0                0  casual dining
# 1                0  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...           1
# 1  2nd floor 80 foot road near big bazaar 6th blo...           0
#
#    online_order  rate  approx_cost(for two people)  \
# 0             1   4.1                        800.0
# 1             1   4.1                        800.0
#
#                                         final_phrase
# 0  casual dining 942 21st main road 2nd stage ban...
# 1  casual dining 2nd floor 80 foot road near big ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features= 1000)

tfidf_matrix = tfidf.fit_transform(df['final_phrase']).toarray()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

cost_matrix = scaler.fit_transform(df.drop(columns= ['rest_type','rate', 'total address','final_phrase']))

# %%
final_matrix = np.hstack((tfidf_matrix, cost_matrix))

final_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  1.69760978,
#          0.63941198,  0.101789  ],
#        [ 0.        ,  0.        ,  0.        , ..., -0.58906352,
#          0.63941198,  0.101789  ],
#        [ 0.        ,  0.        ,  0.        , ..., -0.58906352,
#          0.63941198,  0.101789  ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., -0.58906352,
#         -1.56393691,  0.8728471 ],
#        [ 0.        ,  0.        ,  0.        , ..., -0.58906352,
#         -1.56393691,  0.101789  ],
#        [ 0.        ,  0.        ,  0.        , ...,  1.69760978,
#         -1.56393691,  3.37878593]])

# %%
df.loc[0:3, ['final_phrase','listed_in(type)', 'book_table', 'online_order', 'approx_cost(for two people)']]
# Out:
#                                         final_phrase  listed_in(type)  \
# 0  casual dining 942 21st main road 2nd stage ban...                0
# 1  casual dining 2nd floor 80 foot road near big ...                0
# 2  cafe casual dining 1112 next kims medical coll...                0
# 3  quick bite 1st floor annakuteera 3rd stage ban...                0
#
#    book_table  online_order  approx_cost(for two people)
# 0           1             1                        800.0
# 1           0             1                        800.0
# 2           0             1                        800.0
# 3           0             0                        300.0

# %%
final_matrix[0:3]
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  1.69760978,
#          0.63941198,  0.101789  ],
#        [ 0.        ,  0.        ,  0.        , ..., -0.58906352,
#          0.63941198,  0.101789  ],
#        [ 0.        ,  0.        ,  0.        , ..., -0.58906352,
#          0.63941198,  0.101789  ]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
network = keras.Sequential([
    layers.Dense(256, activation='relu',input_shape=(final_matrix.shape[1],)),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='softplus'),
    layers.Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
network.compile(optimizer='adam', loss='mean_squared_error', metrics= ['mae'])

# %%
history =network.fit(final_matrix, df['rate'], epochs= 100, batch_size=400, validation_split=0.2, verbose= 1)
# Out:
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 3.3069 - mae: 1.3520 - val_loss: 0.2197 - val_mae: 0.3661
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1821 - mae: 0.3248 - val_loss: 0.1683 - val_mae: 0.3199
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1376 - mae: 0.2801 - val_loss: 0.1459 - val_mae: 0.2934
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1199 - mae: 0.2591 - val_loss: 0.1322 - val_mae: 0.2759
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.1080 - mae: 0.2443 - val_loss: 0.1246 - val_mae: 0.2677
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1000 - mae: 0.2341 - val_loss: 0.1157 - val_mae: 0.2519
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0916 - mae: 0.2222 - val_loss: 0.1135 - val_mae: 0.2512
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0862 - mae: 0.2156 - val_loss: 0.1063 - val_mae: 0.2401
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0793 - mae: 0.2062 - val_loss: 0.1034 - val_mae: 0.2355
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0743 - mae: 0.1981 - val_loss: 0.1028 - val_mae: 0.2377
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0691 - mae: 0.1912 - val_loss: 0.1018 - val_mae: 0.2386
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0644 - mae: 0.1839 - val_loss: 0.0936 - val_mae: 0.2215
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0600 - mae: 0.1777 - val_loss: 0.0898 - val_mae: 0.2172
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0559 - mae: 0.1713 - val_loss: 0.0917 - val_mae: 0.2238
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0513 - mae: 0.1636 - val_loss: 0.0834 - val_mae: 0.2047
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0478 - mae: 0.1584 - val_loss: 0.0876 - val_mae: 0.2167
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0461 - mae: 0.1550 - val_loss: 0.0836 - val_mae: 0.2084
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0424 - mae: 0.1497 - val_loss: 0.0831 - val_mae: 0.2104
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0395 - mae: 0.1435 - val_loss: 0.0779 - val_mae: 0.1996
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0372 - mae: 0.1390 - val_loss: 0.0749 - val_mae: 0.1914
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0348 - mae: 0.1341 - val_loss: 0.0749 - val_mae: 0.1912
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0331 - mae: 0.1303 - val_loss: 0.0736 - val_mae: 0.1894
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0314 - mae: 0.1276 - val_loss: 0.0715 - val_mae: 0.1848
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0298 - mae: 0.1235 - val_loss: 0.0675 - val_mae: 0.1738
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0289 - mae: 0.1225 - val_loss: 0.0675 - val_mae: 0.1733
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0275 - mae: 0.1179 - val_loss: 0.0717 - val_mae: 0.1844
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0262 - mae: 0.1148 - val_loss: 0.0671 - val_mae: 0.1774
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0254 - mae: 0.1132 - val_loss: 0.0721 - val_mae: 0.1912
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0243 - mae: 0.1107 - val_loss: 0.0686 - val_mae: 0.1800
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0232 - mae: 0.1081 - val_loss: 0.0687 - val_mae: 0.1819
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0228 - mae: 0.1067 - val_loss: 0.0640 - val_mae: 0.1667
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0214 - mae: 0.1036 - val_loss: 0.0643 - val_mae: 0.1699
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0212 - mae: 0.1028 - val_loss: 0.0652 - val_mae: 0.1712
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0204 - mae: 0.1010 - val_loss: 0.0643 - val_mae: 0.1711
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0197 - mae: 0.0995 - val_loss: 0.0619 - val_mae: 0.1631
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0192 - mae: 0.0975 - val_loss: 0.0629 - val_mae: 0.1647
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0186 - mae: 0.0967 - val_loss: 0.0621 - val_mae: 0.1683
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0178 - mae: 0.0940 - val_loss: 0.0633 - val_mae: 0.1685
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0176 - mae: 0.0928 - val_loss: 0.0627 - val_mae: 0.1685
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0168 - mae: 0.0912 - val_loss: 0.0630 - val_mae: 0.1692
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0167 - mae: 0.0911 - val_loss: 0.0606 - val_mae: 0.1612
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0162 - mae: 0.0900 - val_loss: 0.0613 - val_mae: 0.1632
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0159 - mae: 0.0884 - val_loss: 0.0604 - val_mae: 0.1620
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0153 - mae: 0.0872 - val_loss: 0.0592 - val_mae: 0.1581
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0149 - mae: 0.0852 - val_loss: 0.0591 - val_mae: 0.1575
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0148 - mae: 0.0855 - val_loss: 0.0583 - val_mae: 0.1550
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0142 - mae: 0.0832 - val_loss: 0.0587 - val_mae: 0.1577
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0140 - mae: 0.0827 - val_loss: 0.0606 - val_mae: 0.1632
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0136 - mae: 0.0821 - val_loss: 0.0580 - val_mae: 0.1547
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0132 - mae: 0.0802 - val_loss: 0.0580 - val_mae: 0.1562
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0131 - mae: 0.0797 - val_loss: 0.0594 - val_mae: 0.1596
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0126 - mae: 0.0781 - val_loss: 0.0581 - val_mae: 0.1527
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0127 - mae: 0.0784 - val_loss: 0.0560 - val_mae: 0.1503
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0125 - mae: 0.0774 - val_loss: 0.0576 - val_mae: 0.1554
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0121 - mae: 0.0763 - val_loss: 0.0573 - val_mae: 0.1574
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0119 - mae: 0.0751 - val_loss: 0.0568 - val_mae: 0.1526
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0119 - mae: 0.0756 - val_loss: 0.0560 - val_mae: 0.1498
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0115 - mae: 0.0748 - val_loss: 0.0569 - val_mae: 0.1537
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0113 - mae: 0.0736 - val_loss: 0.0581 - val_mae: 0.1584
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0112 - mae: 0.0732 - val_loss: 0.0566 - val_mae: 0.1517
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0108 - mae: 0.0716 - val_loss: 0.0574 - val_mae: 0.1574
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0108 - mae: 0.0723 - val_loss: 0.0552 - val_mae: 0.1473
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0105 - mae: 0.0709 - val_loss: 0.0556 - val_mae: 0.1484
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0106 - mae: 0.0702 - val_loss: 0.0552 - val_mae: 0.1472
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0104 - mae: 0.0701 - val_loss: 0.0551 - val_mae: 0.1476
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0100 - mae: 0.0690 - val_loss: 0.0561 - val_mae: 0.1534
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0100 - mae: 0.0686 - val_loss: 0.0549 - val_mae: 0.1476
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0098 - mae: 0.0677 - val_loss: 0.0551 - val_mae: 0.1491
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0097 - mae: 0.0677 - val_loss: 0.0553 - val_mae: 0.1517
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0095 - mae: 0.0669 - val_loss: 0.0544 - val_mae: 0.1459
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0095 - mae: 0.0663 - val_loss: 0.0556 - val_mae: 0.1505
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0095 - mae: 0.0665 - val_loss: 0.0547 - val_mae: 0.1459
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0090 - mae: 0.0646 - val_loss: 0.0548 - val_mae: 0.1478
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0088 - mae: 0.0645 - val_loss: 0.0539 - val_mae: 0.1437
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0087 - mae: 0.0638 - val_loss: 0.0545 - val_mae: 0.1455
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0089 - mae: 0.0643 - val_loss: 0.0542 - val_mae: 0.1469
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0088 - mae: 0.0639 - val_loss: 0.0531 - val_mae: 0.1419
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0086 - mae: 0.0634 - val_loss: 0.0529 - val_mae: 0.1413
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0084 - mae: 0.0622 - val_loss: 0.0520 - val_mae: 0.1414
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0083 - mae: 0.0621 - val_loss: 0.0542 - val_mae: 0.1492
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0084 - mae: 0.0621 - val_loss: 0.0528 - val_mae: 0.1406
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0083 - mae: 0.0619 - val_loss: 0.0516 - val_mae: 0.1411
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0083 - mae: 0.0621 - val_loss: 0.0517 - val_mae: 0.1388
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0081 - mae: 0.0608 - val_loss: 0.0520 - val_mae: 0.1396
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0078 - mae: 0.0599 - val_loss: 0.0515 - val_mae: 0.1372
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0078 - mae: 0.0601 - val_loss: 0.0519 - val_mae: 0.1412
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0078 - mae: 0.0596 - val_loss: 0.0514 - val_mae: 0.1417
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0076 - mae: 0.0587 - val_loss: 0.0514 - val_mae: 0.1400
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0073 - mae: 0.0580 - val_loss: 0.0508 - val_mae: 0.1352
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0074 - mae: 0.0579 - val_loss: 0.0521 - val_mae: 0.1366
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0072 - mae: 0.0576 - val_loss: 0.0520 - val_mae: 0.1389
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0072 - mae: 0.0571 - val_loss: 0.0522 - val_mae: 0.1412
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0074 - mae: 0.0581 - val_loss: 0.0504 - val_mae: 0.1377
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0071 - mae: 0.0572 - val_loss: 0.0511 - val_mae: 0.1379
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0070 - mae: 0.0567 - val_loss: 0.0507 - val_mae: 0.1347
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0071 - mae: 0.0569 - val_loss: 0.0515 - val_mae: 0.1391
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0070 - mae: 0.0569 - val_loss: 0.0496 - val_mae: 0.1368
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0068 - mae: 0.0557 - val_loss: 0.0509 - val_mae: 0.1359
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0067 - mae: 0.0555 - val_loss: 0.0502 - val_mae: 0.1339
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0066 - mae: 0.0554 - val_loss: 0.0509 - val_mae: 0.1392
