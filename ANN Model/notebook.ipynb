# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik5412/Deep-Learning-Projects/blob/main/ANN%20Model/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/zomato.csv', engine= 'python', on_bad_lines='skip')

df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
print(df.shape)
df.isna().sum()
# Out:
# (51155, 17)
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1203
# location                          21
# rest_type                        224
# dish_liked                     28074
# cuisines                          45
# approx_cost(for two people)      344
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
print(df.columns)
unwanted_cols = ['menu_item','phone']

df= df.drop(columns=unwanted_cols)

df.head(2)
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes      location      rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari  Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
#
#                                         reviews_list listed_in(type)  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...          Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari

# %%
df['total address'] = df['address'] + ', ' +df['location'] + ', ' +  df['listed_in(city)']
df['food items'] = df['dish_liked'] + ', ' +df['cuisines']
original_df = df.copy()

df = df[['listed_in(type)','rest_type','total address','book_table','online_order', 'rate', 'approx_cost(for two people)']]
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address book_table online_order  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...        Yes          Yes
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         No          Yes
#
#     rate approx_cost(for two people)
# 0  4.1/5                         800
# 1  4.1/5                         800

# %%
df.to_csv('cleaned_df.csv')

# %%
from nltk.tag.brill import Word
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lematizer = WordNetLemmatizer()

def preprocessing_data (text) -> str:

    text = str(text)
    # Converting the text into lower case
    text = text.lower()

    # Removing punctuvations
    text = re.sub(r'[^a-zA-Z0-9\s]','',text)

    # Removing stop words
    words = [w for w in text.split() if w not in stop_words]

    # Lemotization
    words = [lematizer.lemmatize(w) for w in words]

    return ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['total address'] = ' - ' + df['total address']
df['total address'] = df['total address'].apply(preprocessing_data)
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address book_table online_order  \
# 0  942 21st main road 2nd stage banashankari bang...        Yes          Yes
# 1  2nd floor 80 foot road near big bazaar 6th blo...         No          Yes
#
#     rate approx_cost(for two people)
# 0  4.1/5                         800
# 1  4.1/5                         800

# %%
df.loc[df['rate'] == 'NEW','rate'] = df['rate'].mode()[0]
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#        '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5', '4.4 /5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5', '3.3 /5',
#        '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5', '3.5 /5',
#        '3.1 /5', '4.8 /5', '2.3 /5', '2.4 /5', '4.7 /5', '2.2 /5',
#        '2.0 /5', '2.1 /5', '1.8 /5'], dtype=object)

# %%
df['rate'] = df['rate'].apply(lambda x: x.replace('/5','')).str.strip().astype('float')
df['book_table'] = df['book_table'].map({'Yes': 1, 'No': 0}).astype('int')
df['online_order'] = df['online_order'].map({'Yes': 1, 'No': 0}).astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22643 entries, 0 to 51153
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listed_in(type)              22643 non-null  object
#  1   rest_type                    22643 non-null  object
#  2   total address                22643 non-null  object
#  3   book_table                   22643 non-null  bool
#  4   online_order                 22643 non-null  bool
#  5   rate                         22643 non-null  float64
#  6   approx_cost(for two people)  22643 non-null  object
# dtypes: bool(2), float64(1), object(4)
# memory usage: 1.1+ MB

# %%
df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  Casual Dining
# 1          Buffet  Casual Dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...        True
# 1  2nd floor 80 foot road near big bazaar 6th blo...       False
#
#    online_order  rate approx_cost(for two people)
# 0          True   4.1                         800
# 1          True   4.1                         800

# %%
df['rest_type'] = df['rest_type'].apply(preprocessing_data)

df.head(2)
# Out:
#   listed_in(type)      rest_type  \
# 0          Buffet  casual dining
# 1          Buffet  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...        True
# 1  2nd floor 80 foot road near big bazaar 6th blo...       False
#
#    online_order  rate approx_cost(for two people)
# 0          True   4.1                         800
# 1          True   4.1                         800

# %%
df['listed_in(type)'] = df['listed_in(type)'].replace('Drinks & nightlife' , 'Drinks and Nightlife')
df['listed_in(type)'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks and Nightlife', 'Pubs and bars'], dtype=object)

# %%
df.head()
# Out:
#   listed_in(type)           rest_type  \
# 0          Buffet       casual dining
# 1          Buffet       casual dining
# 2          Buffet  cafe casual dining
# 3          Buffet          quick bite
# 4          Buffet       casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...        True
# 1  2nd floor 80 foot road near big bazaar 6th blo...       False
# 2  1112 next kims medical college 17th cross 2nd ...       False
# 3  1st floor annakuteera 3rd stage banashankari b...       False
# 4  10 3rd floor lakshmi associate gandhi bazaar m...       False
#
#    online_order  rate approx_cost(for two people)
# 0          True   4.1                         800
# 1          True   4.1                         800
# 2          True   3.8                         800
# 3         False   3.7                         300
# 4         False   3.8                         600

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df['listed_in(type)'] = label_encoder.fit_transform(df['listed_in(type)'])
df.head(2)
# Out:
#    listed_in(type)      rest_type  \
# 0                0  casual dining
# 1                0  casual dining
#
#                                        total address  book_table  \
# 0  942 21st main road 2nd stage banashankari bang...        True
# 1  2nd floor 80 foot road near big bazaar 6th blo...       False
#
#    online_order  rate approx_cost(for two people)
# 0          True   4.1                         800
# 1          True   4.1                         800
